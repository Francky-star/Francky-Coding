# %%
import pandas as pd
my_file = {'NAME': ['Inn', 'Miles', 'Bal', 'SamSam', 'Lunes', 'Lustres', 'Crepuscule', 'Ciel', 'Sinai', 'Tides', 'Vale', 'Lake', 'Flare', 'Gates', 'Pamela'],
'DESTINATION': ['UK', 'Ivory Coast', 'UK', 'UK', 'Ivory Coast', 'UK', 'France', 'France', 'France', 'Ivory Coast', 'Spain', 'Spain', 'Italy', 'Ghana', 'Italy'],
'FEEDBACKS': [9, 7, 8, 9, 8, 9, 5, 8, 10, 5, 9, 7, 4, 9, 7],
'STAR RATINGS\n /5': [5, 4, 5, 4, 3, 4, 2, 4, 5, 2, 5, 0, 2, 5, 1],
'ALL-INC.\n ROOMS': [8, 10, 8, 4, 7, 9, 6, 2, 5, 5, 3, 18, 8, 13, 6],
'CITY': ['London', 'Abidjan', 'Birmingham', 'Isle Of Wight', 'Yamoussoukro', 'Wolverhampton', 'Paris', 'Marseille', 'Lille', 'Toumodi', 'Madrid', 'Barcelona', 'Milan', 'Accra', 'Venice']}
frame = pd.DataFrame(my_file)
df = frame
df.to_csv('Holiday Destinations.csv')

# Filter the data by score above 8
print(df.iloc[0]), print(df.iloc[3]), print(df.iloc[5]), print(df.iloc[8]), print(df.iloc[10]), print(df.iloc[13])

# Filter the data by score below 2
print('None')

# Correlation
df.corr()

# Chart
df.groupby('DESTINATION').count().plot.pie(y='FEEDBACKS')
# Out:
# NAME                    Inn
# DESTINATION              UK
# FEEDBACKS                 9
# STAR RATINGS\n /5         5
# ALL-INC.\n ROOMS          8
# CITY                 London
# Name: 0, dtype: object
# NAME                        SamSam
# DESTINATION                     UK
# FEEDBACKS                        9
# STAR RATINGS\n /5                4
# ALL-INC.\n ROOMS                 4
# CITY                 Isle Of Wight
# Name: 3, dtype: object
# NAME                       Lustres
# DESTINATION                     UK
# FEEDBACKS                        9
# STAR RATINGS\n /5                4
# ALL-INC.\n ROOMS                 9
# CITY                 Wolverhampton
# Name: 5, dtype: object
# NAME                  Sinai
# DESTINATION          France
# FEEDBACKS                10
# STAR RATINGS\n /5         5
# ALL-INC.\n ROOMS          5
# CITY                  Lille
# Name: 8, dtype: object
# NAME                   Vale
# DESTINATION           Spain
# FEEDBACKS                 9
# ...
